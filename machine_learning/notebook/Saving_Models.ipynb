# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import joblib
import pickle

# %%
df = pd.DataFrame({
    'area': [2600, 3000, 3200, 3600, 4000],
    'price': [550000, 565000, 610000, 680000, 725000]
})

df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model = LinearRegression()
model.fit(df[['area']], df['price'])
prediction = model.predict([[5000]])
prediction[0]
# Out:
# /run/media/galib/Developer/AI-Olympiad/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(859554.7945205481)

# %%
plt.xlabel('Area (sq ft)')
plt.ylabel('Price (USD)')
plt.scatter(df['area'], df['price'], color='green', marker='*')
plt.plot(df['area'], model.predict(df[['area']]), color='blue')

# %%
print(model.coef_[0])
print(model.intercept_)
# Out:
# 135.78767123287673
# 180616.43835616432

# %%
d = pd.DataFrame({
    'area' : [1000, 1500, 2300, 3540, 4120, 4560, 5490, 3460, 4750, 2300, 9000, 8600, 7100 ]
})
d['price'] = model.predict(d[['area']])
d['price'] = d['price'].astype(int)
d
# Out:
#     area    price
# 0   1000   316404
# 1   1500   384297
# 2   2300   492928
# 3   3540   661304
# 4   4120   740061
# 5   4560   799808
# 6   5490   926090
# 7   3460   650441
# 8   4750   825607
# 9   2300   492928
# 10  9000  1402705
# 11  8600  1348390
# 12  7100  1144708

# %% [markdown]
# # Exercise

# %%
data = pd.read_csv('Dataset/data/canada_per_capita_income.csv')
data
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
model.fit(data[['year']], data['per capita income (US$)'])
prediction1 = model.predict([[2020]])
prediction1[0]
# Out:
# /run/media/galib/Developer/AI-Olympiad/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(41288.69409441762)

# %% [markdown]
# # Save Model

# %% [markdown]
# ## Save the Model

# %%
# using pickle

# with open('Models/LinearRegressionModel.pickle', 'wb') as f:
#     pickle.dump(model, f)

# Using joblib

joblib.dump(model, 'Models/LinearRegressionModel.joblib')
# Out:
# ['Models/LinearRegressionModel.joblib']

# %% [markdown]
# ## Reuse Save Model

# %%
# Using pickle

# model = pickle.load(open('Models/LinearRegressionModel.pickle', 'rb'))

# Using joblib

model = joblib.load('Models/LinearRegressionModel.joblib')

# %% [markdown]
# ## Use the Model

# %%
model.predict([[2020]])
# Out:
# /run/media/galib/Developer/AI-Olympiad/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
