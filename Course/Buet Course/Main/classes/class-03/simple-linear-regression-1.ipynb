# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student-scores.csv')
print(df.columns)
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
feature_name = ['Hours']
label = 'Scores'
X = df[feature_name]
y = df[label]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = model.predict(X_test)
print(y_hat)
print(list(y_test))
# Out:
# [77.21667132 87.55530959 21.76397516 18.00447033 36.80199446 59.3590234
#  39.62162307]
# [86, 95, 24, 20, 30, 62, 35]

# %% [markdown]
# metrics

# %%
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

print("The mean sqaure error is : " , mean_squared_error(y_test, y_hat))
print("The root mean sqaure error is : " , root_mean_squared_error(y_test, y_hat))
print("The r-square score is : ", r2_score(y_test, y_hat))
# Out:
# The mean sqaure error is :  30.879072780692756
# The root mean sqaure error is :  5.556894166770927
# The r-square score is :  0.9618469270701008

# %% [markdown]
# Visualising the Training results

# %%
plt.scatter(X_train , y_train, color = 'red')
plt.plot(X_train , model.predict(X_train), color ='blue')

# %% [markdown]
# Visualizing the test results

# %%
plt.scatter(X_test , y_test, color = 'red')
plt.plot(X_test , model.predict(X_test), color ='blue')
